# %% [markdown]
# # ONE PIECE ARC

# %% [markdown]
# ### Importing image as an example for the project

# %%
from skimage import io
img = io.imread("One Piece.png")
io.imshow(img)

# %% [markdown]
# ### Step 1: Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
plt.rcParams['figure.figsize'] = (18,9)
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['font.style'] = "oblique"

# %% [markdown]
# ### Step 2: Reading the data

# %%
data = pd.read_csv("OnePieceArcs.csv")
data
# Out:
#                         Arc  Start onChapter  TotalChapters  TotalPages  \
# 0          Romance Dawn Arc                1              7         178
# 1           Orange Town Arc                8             14         273
# 2         Syrup Village Arc               22             20         396
# 3               Baratie Arc               42             27         514
# 4           Arlong Park Arc               69             27         514
# 5      Buggy Side Story Arc                0              0           0
# 6             Loguetown Arc               96              5         100
# 7        Warship Island Arc                0              0           0
# 8      Reverse Mountain Arc              101              5          96
# 9          Whiskey Peak Arc              106              9         169
# 10    Koby and Helmeppo Arc                0              0           0
# 11        Little Garden Arc              115             15         288
# 12          Drum Island Arc              130             25         477
# 13             Alabasta Arc              155             63        1199
# 14        Post-Alabasta Arc                0              0           0
# 15          Goat Island Arc                0              0           0
# 16        Ruluka Island Arc                0              0           0
# 17                 Jaya Arc              218             19         361
# 18              Skypiea Arc              237             66        1242
# 19                  G-8 Arc                0              0           0
# 20  Long Ring Long Land Arc              303             19         365
# 21        Ocean's Dream Arc                0              0           0
# 22        Foxy's Return Arc                0              0           0
# 23              Water 7 Arc              322             53        1009
# 24          Enies Lobby Arc              375             56        1060
# 25     Post-Enies Lobby Arc              431             11         209
# 26           Ice Hunter Arc                0              0           0
# 27        Thriller Bark Arc              442             48         912
# 28           Spa Island Arc                0              0           0
# 29  Sabaody Archipelago Arc              490             24         456
# 30   Special Historical Arc                0              0           0
# 31          Amazon Lily Arc              514             11         209
# 32           Impel Down Arc              525             25         473
# 33     Little East Blue Arc                0              0           0
# 34           Marineford Arc              550             31         529
# 35             Post-War Arc              581             17         317
# 36    Return to Sabaody Arc              598              5          98
# 37       Fishman Island Arc              603             51         933
# 38         Z's Ambition Arc                0              0           0
# 39          Punk Hazard Arc              654             46         856
# 40     Caesar Retrieval Arc                0              0           0
# 41            Dressrosa Arc              700            102        1830
# 42          Silver Mine Arc                0              0           0
# 43                  Zou Arc              802             23         397
# 44        Marine Rookie Arc                0              0           0
# 45    Whole Cake Island Arc              825             78        1349
# 46               Levely Arc              903              6         100
# 47  Wano Country Arc: Act 1              909             16         278
# 48          Cidre Guild Arc                0              0           0
# 49  Wano Country Arc: Act 2              925             33         560
# 50  Wano Country Arc: Act 3              958             99        1709
#
#    Manga%  Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 0    0.9%                1              3                    72   0.3%
# 1    1.4%                4              5                   120   0.5%
# 2    2.0%                9             10                   240   1.0%
# 3    2.6%               19             12                   288   1.2%
# 4    2.6%               31             15                   360   1.5%
# 5    0.0%               46              2                    48   0.2%
# 6    0.5%               48              6                   144   0.6%
# 7    0.0%               54              8                   192   0.8%
# 8    0.5%               62              2                    48   0.2%
# 9    0.9%               64              4                    96   0.4%
# 10   0.0%               68              2                    48   0.2%
# 11   1.5%               70              8                   192   0.8%
# 12   2.5%               78             14                   336   1.4%
# 13   6.2%               92             39                   936   3.8%
# 14   0.0%              131              5                   120   0.5%
# 15   0.0%              136              3                    72   0.3%
# 16   0.0%              139              5                   120   0.5%
# 17   1.9%              144              9                   216   0.9%
# 18   6.4%              153             43                  1032   4.2%
# 19   0.0%              196             11                   264   1.1%
# 20   1.9%              207             15                   360   1.5%
# 21   0.0%              220              5                   120   0.5%
# 22   0.0%              225              2                    48   0.2%
# 23   5.2%              229             35                   840   3.4%
# 24   5.4%              264             49                  1176   4.8%
# 25   1.1%              313             13                   312   1.3%
# 26   0.0%              326             11                   264   1.1%
# 27   4.7%              337             45                  1080   4.4%
# 28   0.0%              382              3                    72   0.3%
# 29   2.3%              385             21                   504   2.0%
# 30   0.0%              406              2                    48   0.2%
# 31   1.1%              408             14                   336   1.4%
# 32   2.4%              422             31                   744   3.0%
# 33   0.0%              426              4                    96   0.4%
# 34   2.7%              457             33                   792   3.2%
# 35   1.6%              490             27                   648   2.6%
# 36   0.5%              517              6                   144   0.6%
# 37   4.8%              523             52                  1248   5.1%
# 38   0.0%              575              4                    96   0.4%
# 39   4.4%              579             47                  1128   4.6%
# 40   0.0%              626              3                    72   0.3%
# 41   9.4%              629            118                  2832  11.5%
# 42   0.0%              747              4                    96   0.4%
# 43   2.0%              751             29                   696   2.8%
# 44   0.0%              780              3                    72   0.3%
# 45   6.9%              783             95                  2280   9.2%
# 46   0.5%              878             12                   288   1.2%
# 47   1.4%              890             26                   624   2.5%
# 48   0.0%              895              2                    48   0.2%
# 49   2.9%              918             41                   984   4.0%
# 50   8.8%              959             70                  1680   6.8%

# %% [markdown]
# ### Step 3: Exploring the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Arc                   51 non-null     object
#  1   Start onChapter       51 non-null     int64
#  2   TotalChapters         51 non-null     int64
#  3   TotalPages            51 non-null     int64
#  4   Manga%                51 non-null     object
#  5   Start onEpisode       51 non-null     int64
#  6   TotalEpisodes         51 non-null     int64
#  7   TotalMinutes(avg 24)  51 non-null     int64
#  8   Anime%                51 non-null     object
# dtypes: int64(6), object(3)
# memory usage: 3.7+ KB

# %%
data.describe()
# Out:
#        Start onChapter  TotalChapters   TotalPages  Start onEpisode  \
# count        51.000000      51.000000    51.000000        51.000000
# mean        268.823529      20.705882   381.490196       354.745098
# std         317.019287      26.133728   471.266268       291.209742
# min           0.000000       0.000000     0.000000         1.000000
# 25%           0.000000       0.000000     0.000000        85.000000
# 50%         106.000000      11.000000   209.000000       313.000000
# 75%         519.500000      27.000000   514.000000       549.000000
# max         958.000000     102.000000  1830.000000       959.000000
#
#        TotalEpisodes  TotalMinutes(avg 24)
# count      51.000000             51.000000
# mean       20.156863            483.764706
# std        24.345326            584.287826
# min         2.000000             48.000000
# 25%         4.000000             96.000000
# 50%        11.000000            264.000000
# 75%        30.000000            720.000000
# max       118.000000           2832.000000

# %%
### Maximum Episode
max_episode = data[data['TotalEpisodes'] == data['TotalEpisodes'].max()]
max_episode
# Out:
#               Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 41  Dressrosa Arc              700            102        1830   9.4%
#
#     Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 41              629            118                  2832  11.5%

# %%
data.tail(5)
# Out:
#                         Arc  Start onChapter  TotalChapters  TotalPages  \
# 46               Levely Arc              903              6         100
# 47  Wano Country Arc: Act 1              909             16         278
# 48          Cidre Guild Arc                0              0           0
# 49  Wano Country Arc: Act 2              925             33         560
# 50  Wano Country Arc: Act 3              958             99        1709
#
#    Manga%  Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 46   0.5%              878             12                   288   1.2%
# 47   1.4%              890             26                   624   2.5%
# 48   0.0%              895              2                    48   0.2%
# 49   2.9%              918             41                   984   4.0%
# 50   8.8%              959             70                  1680   6.8%

# %%
# Since Wano is suppose be the longest arc, we need to show this based on that
# let us combine all the acts in Wano together
wanoData = data.loc[47:50]
wanoData.drop(48,axis=0,inplace=True)

# %%
wanoTotalChapters = sum(wanoData['TotalChapters'])
wanoTotalPages = sum(wanoData['TotalPages'])
wanoMangaPercent = "{:.1f}".format(wanoTotalChapters/sum(data['TotalChapters'])*100)+"%"

wanoTotalEpisode = sum(wanoData['TotalEpisodes'])
wanoTotalMinutes = sum(wanoData['TotalMinutes(avg 24)'])
wanoAnimePercent = "{:.1f}".format(wanoTotalEpisode/sum(data['TotalEpisodes'])*100)+"%"

# %%
data.loc[len(data.index)] = ['Wano Country Arc',909,wanoTotalChapters,wanoTotalPages,wanoMangaPercent,890,wanoTotalEpisode,wanoTotalMinutes,wanoAnimePercent]

# %%
data.tail(5)
# Out:
#                         Arc  Start onChapter  TotalChapters  TotalPages  \
# 47  Wano Country Arc: Act 1              909             16         278
# 48          Cidre Guild Arc                0              0           0
# 49  Wano Country Arc: Act 2              925             33         560
# 50  Wano Country Arc: Act 3              958             99        1709
# 51         Wano Country Arc              909            148        2547
#
#    Manga%  Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 47   1.4%              890             26                   624   2.5%
# 48   0.0%              895              2                    48   0.2%
# 49   2.9%              918             41                   984   4.0%
# 50   8.8%              959             70                  1680   6.8%
# 51  14.0%              890            137                  3288  13.3%

# %%
data.drop(wanoData.index,axis=0,inplace=True)

# %%
data.tail()
# Out:
#                       Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 44      Marine Rookie Arc                0              0           0   0.0%
# 45  Whole Cake Island Arc              825             78        1349   6.9%
# 46             Levely Arc              903              6         100   0.5%
# 48        Cidre Guild Arc                0              0           0   0.0%
# 51       Wano Country Arc              909            148        2547  14.0%
#
#     Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 44              780              3                    72   0.3%
# 45              783             95                  2280   9.2%
# 46              878             12                   288   1.2%
# 48              895              2                    48   0.2%
# 51              890            137                  3288  13.3%

# %%
# Maximum episode
max_episode = data[data['TotalEpisodes'] == data['TotalEpisodes'].max()]
print(f"{max_episode.iloc[0].values[0]} has highest number of episodes: {max_episode.iloc[0].values[-3]} episodes")
max_episode
# Out:
# Wano Country Arc has highest number of episodes: 137 episodes
#                  Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 51  Wano Country Arc              909            148        2547  14.0%
#
#     Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 51              890            137                  3288  13.3%

# %%
# Maximum watch time
max_watchTime = data[data['TotalMinutes(avg 24)'] == data['TotalMinutes(avg 24)'].max()]
print(f"{max_episode.iloc[0].values[0]} has highest maximum watch Time: {max_episode.iloc[0].values[-2]} minutes")
max_watchTime
# Out:
# Wano Country Arc has highest maximum watch Time: 3288 minutes
#                  Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 51  Wano Country Arc              909            148        2547  14.0%
#
#     Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 51              890            137                  3288  13.3%

# %%
# Top 5 longest running arc in anime
df_run = pd.DataFrame({'Arc':data['Arc'],'TotalMinutes(avg 24)':data['TotalMinutes(avg 24)']})
df_run.sort_values(by='TotalMinutes(avg 24)',ascending=False).reset_index().head()
# Out:
#    index                    Arc  TotalMinutes(avg 24)
# 0     51       Wano Country Arc                  3288
# 1     41          Dressrosa Arc                  2832
# 2     45  Whole Cake Island Arc                  2280
# 3     37     Fishman Island Arc                  1248
# 4     24        Enies Lobby Arc                  1176

# %%
# Top 5 longest running arc in manga
df_run = pd.DataFrame({'Arc':data['Arc'],'TotalPages':data['TotalPages']})
df_run.sort_values(by='TotalPages',ascending=False).reset_index().head()
# Out:
#    index                    Arc  TotalPages
# 0     51       Wano Country Arc        2547
# 1     41          Dressrosa Arc        1830
# 2     45  Whole Cake Island Arc        1349
# 3     18            Skypiea Arc        1242
# 4     13           Alabasta Arc        1199

# %%
# Filter % symbol from Manga% and Anime%
def filter_percent(data):
    return data[:-1]

# %%
data['Manga%'] = data['Manga%'].apply(filter_percent).astype(float)
data['Anime%'] = data['Anime%'].apply(filter_percent).astype(float)

# %%
data.sample(5)
# Out:
#                       Arc  Start onChapter  TotalChapters  TotalPages  Manga%  \
# 45  Whole Cake Island Arc              825             78        1349     6.9
# 21      Ocean's Dream Arc                0              0           0     0.0
# 16      Ruluka Island Arc                0              0           0     0.0
# 39        Punk Hazard Arc              654             46         856     4.4
# 32         Impel Down Arc              525             25         473     2.4
#
#     Start onEpisode  TotalEpisodes  TotalMinutes(avg 24)  Anime%
# 45              783             95                  2280     9.2
# 21              220              5                   120     0.5
# 16              139              5                   120     0.5
# 39              579             47                  1128     4.6
# 32              422             31                   744     3.0

# %% [markdown]
# ### Step 4: Visualizing the data

# %%
# Barplot can visualization allows you to examine data distribution
sns.barplot(data['Arc'],data['TotalEpisodes'])
plt.xticks(rotation=90)
plt.xlabel("ARC")
plt.ylabel("TOTAL EPISODE")
plt.title("ARC VS TOTAL EPISODE",fontsize=24)
# Out:
# Text(0.5, 1.0, 'ARC VS TOTAL EPISODE')

# %%
# Barplot can visualization allows you to examine data distribution
sns.barplot(data['Arc'],data['TotalChapters'])
plt.xticks(rotation=90)
plt.xlabel("ARC")
plt.ylabel("TOTAL CHAPTERS")
plt.title("ARC VS TOTAL CHAPTERS",fontsize=24)
# Out:
# Text(0.5, 1.0, 'ARC VS TOTAL CHAPTERS')

# %%
# Histogram based on Total episodes
ax = px.histogram(data,x='TotalEpisodes',marginal="box",nbins=18)
ax.update_layout(bargap=0.2)
# Out:
# <div>                            <div id="4aba7dcf-eab1-443f-b7e0-b735bf31b5bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aba7dcf-eab1-443f-b7e0-b735bf31b5bc")) {                    Plotly.newPlot(                        "4aba7dcf-eab1-443f-b7e0-b735bf31b5bc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TotalEpisodes=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":18,"offsetgroup":"","orientation":"v","showlegend":false,"x":[3,5,10,12,15,2,6,8,2,4,2,8,14,39,5,3,5,9,43,11,15,5,2,35,49,13,11,45,3,21,2,14,31,4,33,27,6,52,4,47,3,118,4,29,3,95,12,2,137],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"TotalEpisodes=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[3,5,10,12,15,2,6,8,2,4,2,8,14,39,5,3,5,9,43,11,15,5,2,35,49,13,11,45,3,21,2,14,31,4,33,27,6,52,4,47,3,118,4,29,3,95,12,2,137],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[ ...

# %%
# Histogram based on Total minutes
ax = px.histogram(data,x='TotalMinutes(avg 24)',marginal="box", nbins=18)
ax.update_layout(bargap=0.2)
# Out:
# <div>                            <div id="2dfe6686-902a-4e83-9654-e7267da98408" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dfe6686-902a-4e83-9654-e7267da98408")) {                    Plotly.newPlot(                        "2dfe6686-902a-4e83-9654-e7267da98408",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TotalMinutes(avg 24)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":18,"offsetgroup":"","orientation":"v","showlegend":false,"x":[72,120,240,288,360,48,144,192,48,96,48,192,336,936,120,72,120,216,1032,264,360,120,48,840,1176,312,264,1080,72,504,48,336,744,96,792,648,144,1248,96,1128,72,2832,96,696,72,2280,288,48,3288],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"TotalMinutes(avg 24)=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[72,120,240,288,360,48,144,192,48,96,48,192,336,936,120,72,120,216,1032,264,360,120,48,840,1176,312,264,1080,72,504,48,336,744,96,792,648,144,1248,96,1128,72,2832,96,696,72,2280,288,48,3288],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %%
# Histogram based on Total chapters
ax = px.histogram(data,x='TotalChapters',marginal="box",nbins=18)
ax.update_layout(bargap=0.2)
# Out:
# <div>                            <div id="95563dc8-d777-4e0c-bc39-99a1b3c4a092" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95563dc8-d777-4e0c-bc39-99a1b3c4a092")) {                    Plotly.newPlot(                        "95563dc8-d777-4e0c-bc39-99a1b3c4a092",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TotalChapters=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":18,"offsetgroup":"","orientation":"v","showlegend":false,"x":[7,14,20,27,27,0,5,0,5,9,0,15,25,63,0,0,0,19,66,0,19,0,0,53,56,11,0,48,0,24,0,11,25,0,31,17,5,51,0,46,0,102,0,23,0,78,6,0,148],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"TotalChapters=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[7,14,20,27,27,0,5,0,5,9,0,15,25,63,0,0,0,19,66,0,19,0,0,53,56,11,0,48,0,24,0,11,25,0,31,17,5,51,0,46,0,102,0,23,0,78,6,0,148],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[ ...

# %%
# Histogram based on Total pages
ax = px.histogram(data,x='TotalPages',marginal="box",nbins=18)
ax.update_layout(bargap=0.2)
# Out:
# <div>                            <div id="75ec10cc-58a9-4d90-9903-944a46652db4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75ec10cc-58a9-4d90-9903-944a46652db4")) {                    Plotly.newPlot(                        "75ec10cc-58a9-4d90-9903-944a46652db4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TotalPages=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":18,"offsetgroup":"","orientation":"v","showlegend":false,"x":[178,273,396,514,514,0,100,0,96,169,0,288,477,1199,0,0,0,361,1242,0,365,0,0,1009,1060,209,0,912,0,456,0,209,473,0,529,317,98,933,0,856,0,1830,0,397,0,1349,100,0,2547],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"TotalPages=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[178,273,396,514,514,0,100,0,96,169,0,288,477,1199,0,0,0,361,1242,0,365,0,0,1009,1060,209,0,912,0,456,0,209,473,0,529,317,98,933,0,856,0,1830,0,397,0,1349,100,0,2547],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444, ...

# %%
# Filler episode list
filler_epsiode = data[data['TotalChapters'] == 0]
filler_epsiode
# Out:
#                        Arc  Start onChapter  TotalChapters  TotalPages  \
# 5     Buggy Side Story Arc                0              0           0
# 7       Warship Island Arc                0              0           0
# 10   Koby and Helmeppo Arc                0              0           0
# 14       Post-Alabasta Arc                0              0           0
# 15         Goat Island Arc                0              0           0
# 16       Ruluka Island Arc                0              0           0
# 19                 G-8 Arc                0              0           0
# 21       Ocean's Dream Arc                0              0           0
# 22       Foxy's Return Arc                0              0           0
# 26          Ice Hunter Arc                0              0           0
# 28          Spa Island Arc                0              0           0
# 30  Special Historical Arc                0              0           0
# 33    Little East Blue Arc                0              0           0
# 38        Z's Ambition Arc                0              0           0
# 40    Caesar Retrieval Arc                0              0           0
# 42         Silver Mine Arc                0              0           0
# 44       Marine Rookie Arc                0              0           0
# 48         Cidre Guild Arc                0              0           0
#
#     Manga%  Start onEpisode  TotalEpisodes  TotalMinutes(avg 24)  Anime%
# 5      0.0               46              2                    48     0.2
# 7      0.0               54              8                   192     0.8
# 10     0.0               68              2                    48     0.2
# 14     0.0              131              5                   120     0.5
# 15     0.0              136              3                    72     0.3
# 16     0.0              139              5                   120     0.5
# 19     0.0              196             11                   264     1.1
# 21     0.0              220              5                   120     0.5
# 22     0.0              225              2                    48     0.2
# 26     0.0              326             11                   264     1.1
# 28     0.0              382              3                    72     0.3
# 30     0.0              406              2                    48     0.2
# 33     0.0              426              4                    96     0.4
# 38     0.0              575              4                    96     0.4
# 40     0.0              626              3                    72     0.3
# 42     0.0              747              4                    96     0.4
# 44     0.0              780              3                    72     0.3
# 48     0.0              895              2                    48     0.2

# %%
# Maximum Episode in a Filler
max_filler_episode = filler_epsiode[filler_epsiode['TotalEpisodes'] == filler_epsiode['TotalEpisodes'].max()]
max_filler_episode
# Out:
#                Arc  Start onChapter  TotalChapters  TotalPages  Manga%  \
# 19         G-8 Arc                0              0           0     0.0
# 26  Ice Hunter Arc                0              0           0     0.0
#
#     Start onEpisode  TotalEpisodes  TotalMinutes(avg 24)  Anime%
# 19              196             11                   264     1.1
# 26              326             11                   264     1.1

# %%
# Minimum Episode in a Filler
min_filler_episode = filler_epsiode[filler_epsiode['TotalEpisodes'] == filler_epsiode['TotalEpisodes'].min()]
min_filler_episode
# Out:
#                        Arc  Start onChapter  TotalChapters  TotalPages  \
# 5     Buggy Side Story Arc                0              0           0
# 10   Koby and Helmeppo Arc                0              0           0
# 22       Foxy's Return Arc                0              0           0
# 30  Special Historical Arc                0              0           0
# 48         Cidre Guild Arc                0              0           0
#
#     Manga%  Start onEpisode  TotalEpisodes  TotalMinutes(avg 24)  Anime%
# 5      0.0               46              2                    48     0.2
# 10     0.0               68              2                    48     0.2
# 22     0.0              225              2                    48     0.2
# 30     0.0              406              2                    48     0.2
# 48     0.0              895              2                    48     0.2
